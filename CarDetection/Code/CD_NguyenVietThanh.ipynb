# %%
pip install ultralytics

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !git clone https://github.com/ultralytics/yolov5.git

# %cd yolov5/

# !pip install -r requirements.txt

# %%
pip install pyyaml

# %%
# lệnh shell rm (remove)
# !rm -r "/content/drive/MyDrive/car-detection-1"

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="mclLHXcZODPiI3gS6M3W")
project = rf.workspace("mit-ivmqi").project("car-detection-xpuvx")
dataset = project.version(3).download("yolov5")

# %%
# %cd /content/drive/MyDrive/yolov5
# Out:
# /content/drive/MyDrive/yolov5

# %%
# !pip install -r requirements.txt

# %%
# Huấn luyện mô hình YOLOv5 trên tập dữ liệu Car Detection 3.
# !python /content/drive/MyDrive/yolov5/train.py --img 640 --batch 16 --epochs 50 --data /content/drive/MyDrive/yolov5/Car-detection-3/data.yaml --weights yolov5s.pt

# !python: là dòng lệnh chạy python
# train.py: Là tên của file python chứa các lệnh để huấn luyện mô hình YOLOv5.
# --img 640: Kích thước ảnh đầu vào để huấn luyện là 640x640 pixel.
# --batch 16: Kích thước batch size là 16.
# --epochs 50: Số lượng epochs để huấn luyện là 50.
# --data /content/drive/MyDrive/yolov5/Car-detection-3/data.yaml:  Đường dẫn đến file data.yaml chứa thông tin về dataset, các class và đường dẫn tới các tệp ảnh và tệp nhãn.
# --weights yolov5s.pt(file trọng số yolov5s): Đường dẫn tới file trọng số của mô hình YOLOv5s (một trong các phiên bản nhỏ nhất của YOLOv5).
# Out:
# requirements: YOLOv5 requirement "gitpython" not found, attempting AutoUpdate...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting gitpython
#   Downloading GitPython-3.1.31-py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 10.6 MB/s eta 0:00:00
# Collecting gitdb<5,>=4.0.1 (from gitpython)
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.7 MB/s eta 0:00:00
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython)
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Installing collected packages: smmap, gitdb, gitpython
# Successfully installed gitdb-4.0.10 gitpython-3.1.31 smmap-5.0.0
#
# requirements: 1 package updated per ['gitpython']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# train: weights=yolov5s.pt, cfg=, data=/content/drive/MyDrive/yolov5/Car-detection-3/data.yaml, hyp=drive/MyDrive/yolov5/data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=drive/MyDrive/yolov5/runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# Command 'git fetch origin' timed out after 5 seconds
# requirements: /content/drive/MyDrive/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-155-g8ecc727 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# ClearML: run 'pip install clearml' to automatically track, visualize and remotely train YOLOv5 🚀 in ClearML
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir drive/MyDrive/yolov5/runs/train', view at http://localhost:6006/
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# remote: Enumerating objects: 19, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 19 (delta 4), reused 8 (delta 1), pack-reused 0
# 100% 755k/755k [00:00<00:00, 41.9MB/s]
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5s.pt to yolov5s.pt...
# Unpacking objects: 100% (19/19), 48.42 KiB | 199.00 KiB/s, done.
# 100% 14.1M/14.1M [00:00<00:00, 58.9MB/s]
#
# Overriding model.yaml nc=80 with nc=1
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     16182  models.yolo.Detect                      [1, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 214 layers, 7022326 parameters, 7022326 gradients
#
# From https://github.com/ultralytics/yolov5
#    c3e4e94..e382d4c  master     -> origin/master
#  * [new branch]      snyk-fix-6c9eeb3b0a7596bd3087093a737a3c49 -> origin/snyk-fix-6c9eeb3b0a7596bd3087093a737a3c49
# Transferred 343/349 items from yolov5s.pt
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# train: Scanning /content/drive/MyDrive/yolov5/Car-detection-3/train/labels.cache... 263 images, 0 backgrounds, 0 corrupt: 100% 263/263 [00:00<?, ?it/s]
# val: Scanning /content/drive/MyDrive/yolov5/Car-detection-3/valid/labels.cache... 75 images, 0 backgrounds, 0 corrupt: 100% 75/75 [00:00<?, ?it/s]
#
# AutoAnchor: 3.09 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to drive/MyDrive/yolov5/runs/train/exp4/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to drive/MyDrive/yolov5/runs/train/exp4
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        0/49      3.46G     0.1164    0.03304          0         18        640: 100% 17/17 [00:15<00:00,  1.10it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:08<00:00,  2.69s/it]
#                    all         75        120     0.0709      0.142     0.0546     0.0149
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        1/49      4.27G    0.08745    0.03234          0         20        640: 100% 17/17 [00:10<00:00,  1.67it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:02<00:00,  1.22it/s]
#                    all         75        120      0.355      0.417      0.277      0.128
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        2/49      4.27G     0.0688    0.02868          0         26        640: 100% 17/17 [00:10<00:00,  1.67it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.65it/s]
#                    all         75        120      0.449      0.515      0.453      0.175
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        3/49      4.27G    0.06486    0.02419          0         21        640: 100% 17/17 [00:10<00:00,  1.67it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.95it/s]
#                    all         75        120      0.563      0.579      0.577      0.219
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        4/49      4.27G    0.06148    0.02272          0         18        640: 100% 17/17 [00:10<00:00,  1.65it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  2.00it/s]
#                    all         75        120      0.661      0.508       0.55      0.268
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        5/49      4.27G    0.05799    0.02376          0         18        640: 100% 17/17 [00:09<00:00,  1.80it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:02<00:00,  1.24it/s]
#                    all         75        120      0.512      0.525      0.472      0.221
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        6/49      4.27G    0.05324    0.02354          0         33        640: 100% 17/17 [00:08<00:00,  2.06it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:02<00:00,  1.35it/s]
#                    all         75        120       0.45      0.477      0.443      0.174
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        7/49      4.27G    0.04912    0.01898          0         21        640: 100% 17/17 [00:09<00:00,  1.86it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.70it/s]
#                    all         75        120      0.577       0.59      0.545      0.303
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        8/49      4.27G    0.04602    0.02068          0         19        640: 100% 17/17 [00:09<00:00,  1.77it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  2.23it/s]
#                    all         75        120       0.48      0.633      0.502      0.225
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        9/49      4.27G    0.04622    0.01761          0         23        640: 100% 17/17 [00:10<00:00,  1.62it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.91it/s]
#                    all         75        120      0.736      0.658      0.698      0.401
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       10/49      4.27G    0.04804    0.02008          0         17        640: 100% 17/17 [00:10<00:00,  1.68it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.84it/s]
#                    all         75        120      0.805      0.667      0.685      0.371
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       11/49      4.27G    0.04231    0.01889          0         30        640: 100% 17/17 [00:10<00:00,  1.66it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.92it/s]
#                    all         75        120      0.765      0.652        0.7      0.366
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       12/49      4.27G    0.04039    0.01773          0         19        640: 100% 17/17 [00:08<00:00,  1.99it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:02<00:00,  1.04it/s]
#                    all         75        120      0.722       0.65      0.694      0.411
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       13/49      4.27G    0.04002    0.01836          0         16        640: 100% 17/17 [00:08<00:00,  2.12it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:02<00:00,  1.29it/s]
#                    all         75        120      0.783      0.723      0.771      0.444
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       14/49      4.27G    0.03942    0.01756          0         26        640: 100% 17/17 [00:07<00:00,  2.18it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.76it/s]
#                    all         75        120      0.802      0.758      0.825      0.443
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       15/49      4.27G    0.03961    0.01739          0         22        640: 100% 17/17 [00:09<00:00,  1.75it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  2.05it/s]
#                    all         75        120       0.77      0.753      0.803      0.512
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       16/49      4.27G    0.03654    0.01669          0         14        640: 100% 17/17 [00:10<00:00,  1.69it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.93it/s]
#                    all         75        120      0.846      0.778      0.838      0.447
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       17/49      4.27G     0.0373    0.01634          0         19        640: 100% 17/17 [00:10<00:00,  1.67it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  2.20it/s]
#                    all         75        120      0.844      0.683      0.792      0.417
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       18/49      4.27G      0.038    0.01718          0         17        640: 100% 17/17 [00:10<00:00,  1.67it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  2.04it/s]
#                    all         75        120      0.808      0.767      0.811      0.426
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       19/49      4.27G    0.03347     0.0163          0         20        640: 100% 17/17 [00:09<00:00,  1.85it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:02<00:00,  1.12it/s]
#                    all         75        120      0.769      0.767      0.768      0.439
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       20/49      4.27G    0.03441    0.01608          0         15        640: 100% 17/17 [00:08<00:00,  2.04it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.74it/s]
#                    all         75        120      0.792        0.8      0.817      0.493
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       21/49      4.27G    0.03425    0.01755          0         31        640: 100% 17/17 [00:09<00:00,  1.76it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.89it/s]
#                    all         75        120      0.791      0.733      0.808      0.514
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       22/49      4.27G    0.03483    0.01616          0         14        640: 100% 17/17 [00:09<00:00,  1.70it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  2.08it/s]
#                    all         75        120      0.879      0.792      0.852      0.526
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       23/49      4.27G    0.03189    0.01512          0         17        640: 100% 17/17 [00:10<00:00,  1.68it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  2.09it/s]
#                    all         75        120       0.82      0.808      0.838      0.521
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       24/49      4.27G    0.03228    0.01799          0         40        640: 100% 17/17 [00:10<00:00,  1.63it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  2.25it/s]
#                    all         75        120       0.82      0.792      0.852      0.548
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       25/49      4.27G    0.03219    0.01659          0         28        640: 100% 17/17 [00:09<00:00,  1.75it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.72it/s]
#                    all         75        120       0.91      0.759      0.866      0.543
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       26/49      4.27G    0.02895    0.01449          0         20        640: 100% 17/17 [00:08<00:00,  2.03it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:02<00:00,  1.22it/s]
#                    all         75        120      0.861        0.8      0.868      0.556
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       27/49      4.27G     0.0298    0.01582          0         22        640: 100% 17/17 [00:07<00:00,  2.18it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.86it/s]
#                    all         75        120      0.881      0.743      0.852      0.528
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       28/49      4.27G    0.02944    0.01535          0         27        640: 100% 17/17 [00:09<00:00,  1.71it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  2.13it/s]
#                    all         75        120      0.893      0.783      0.872      0.556
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       29/49      4.27G    0.02821    0.01371          0         17        640: 100% 17/17 [00:10<00:00,  1.67it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  2.07it/s]
#                    all         75        120       0.91      0.757      0.858      0.558
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       30/49      4.27G    0.02868    0.01451          0         29        640: 100% 17/17 [00:10<00:00,  1.63it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.90it/s]
#                    all         75        120      0.913       0.75      0.869      0.598
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       31/49      4.27G    0.02815    0.01434          0         12        640: 100% 17/17 [00:10<00:00,  1.68it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.71it/s]
#                    all         75        120      0.838      0.817      0.857      0.592
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       32/49      4.27G     0.0272     0.0144          0         13        640: 100% 17/17 [00:09<00:00,  1.85it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:02<00:00,  1.20it/s]
#                    all         75        120      0.958      0.764      0.875      0.595
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       33/49      4.27G    0.02595    0.01345          0         14        640: 100% 17/17 [00:08<00:00,  1.95it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:02<00:00,  1.21it/s]
#                    all         75        120      0.901      0.758      0.866      0.598
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       34/49      4.27G    0.02803    0.01487          0         25        640: 100% 17/17 [00:08<00:00,  2.02it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.75it/s]
#                    all         75        120      0.877      0.775      0.859      0.595
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       35/49      4.27G    0.02514    0.01367          0         13        640: 100% 17/17 [00:10<00:00,  1.67it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.98it/s]
#                    all         75        120      0.895      0.808      0.872      0.623
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       36/49      4.27G    0.02801    0.01566          0         32        640: 100% 17/17 [00:10<00:00,  1.70it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.96it/s]
#                    all         75        120      0.896      0.783      0.868      0.611
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       37/49      4.27G    0.02514    0.01365          0         24        640: 100% 17/17 [00:10<00:00,  1.65it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.95it/s]
#                    all         75        120      0.914      0.799      0.876      0.629
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       38/49      4.27G    0.02448    0.01398          0         22        640: 100% 17/17 [00:10<00:00,  1.70it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.91it/s]
#                    all         75        120      0.908      0.792      0.874      0.627
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       39/49      4.27G    0.02472    0.01376          0         23        640: 100% 17/17 [00:09<00:00,  1.88it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:02<00:00,  1.08it/s]
#                    all         75        120      0.908        0.8       0.87      0.634
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       40/49      4.27G    0.02508    0.01322          0         27        640: 100% 17/17 [00:08<00:00,  2.05it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:02<00:00,  1.26it/s]
#                    all         75        120      0.916      0.814      0.878      0.633
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       41/49      4.27G    0.02213    0.01439          0         39        640: 100% 17/17 [00:08<00:00,  2.12it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.92it/s]
#                    all         75        120      0.925      0.818      0.887      0.633
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       42/49      4.27G    0.02323     0.0132          0         21        640: 100% 17/17 [00:10<00:00,  1.69it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  2.00it/s]
#                    all         75        120      0.907       0.81      0.891      0.625
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       43/49      4.27G    0.02236    0.01292          0         32        640: 100% 17/17 [00:10<00:00,  1.65it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  2.44it/s]
#                    all         75        120      0.925      0.817      0.902      0.646
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       44/49      4.27G     0.0227    0.01325          0         22        640: 100% 17/17 [00:10<00:00,  1.66it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  2.10it/s]
#                    all         75        120      0.893      0.842      0.889      0.633
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       45/49      4.27G    0.02125    0.01226          0         14        640: 100% 17/17 [00:09<00:00,  1.77it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:02<00:00,  1.36it/s]
#                    all         75        120      0.926      0.792      0.884      0.628
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       46/49      4.27G    0.02207    0.01215          0         15        640: 100% 17/17 [00:07<00:00,  2.21it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:02<00:00,  1.20it/s]
#                    all         75        120      0.932      0.798      0.884      0.629
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       47/49      4.27G    0.02205    0.01383          0         13        640: 100% 17/17 [00:08<00:00,  1.99it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  2.05it/s]
#                    all         75        120      0.914      0.794      0.884      0.637
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       48/49      4.27G    0.02166    0.01333          0         26        640: 100% 17/17 [00:10<00:00,  1.67it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.92it/s]
#                    all         75        120      0.932        0.8      0.886      0.636
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       49/49      4.27G    0.02046    0.01328          0         22        640: 100% 17/17 [00:09<00:00,  1.70it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  2.04it/s]
#                    all         75        120      0.931      0.789      0.883       0.64
#
# 50 epochs completed in 0.182 hours.
# Optimizer stripped from drive/MyDrive/yolov5/runs/train/exp4/weights/last.pt, 14.4MB
# Optimizer stripped from drive/MyDrive/yolov5/runs/train/exp4/weights/best.pt, 14.4MB
#
# Validating drive/MyDrive/yolov5/runs/train/exp4/weights/best.pt...
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:02<00:00,  1.30it/s]
#                    all         75        120      0.925      0.817      0.903      0.648
# Results saved to drive/MyDrive/yolov5/runs/train/exp4

# %%
# Chạy tập lệnh phát hiện YOLOv5 (detect.py) bằng cách sử dụng mô hình được đào tạo (best.pt) 
# và phát hiện các đối tượng trong hình ảnh có trong thư mục đã chỉ định
# !python "/content/drive/MyDrive/yolov5/detect.py" --weights "/content/drive/MyDrive/yolov5/runs/train/exp4/weights/best.pt" --img 640 --conf 0.25 --source "/content/drive/MyDrive/yolov5/Car-detection-3/test/images"

# !python: là dòng lệnh chạy python
# --weights: Chỉ định đường dẫn đến mô hình YOLOv5 đã đào tạo (best.pt) sẽ được sử dụng để phát hiện đối tượng.
# --img 640: Đặt kích thước hình ảnh đầu vào để phát hiện đối tượng.
# --conf 0.25: Đặt ngưỡng tin cậy để phát hiện đối tượng. 
# Các đối tượng được phát hiện có điểm tin cậy thấp hơn 0,25 sẽ bị lọc ra.
# --source: Chỉ định thư mục chứa các hình ảnh thử nghiệm để phát hiện đối tượng.
# Out:
# detect: weights=['/content/drive/MyDrive/yolov5/runs/train/exp4/weights/best.pt'], source=/content/drive/MyDrive/yolov5/Car-detection-3/test/images, data=drive/MyDrive/yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=drive/MyDrive/yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# requirements: /content/drive/MyDrive/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-155-g8ecc727 Python-3.10.11 torch-2.0.0+cu118 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients
# image 1/39 /content/drive/MyDrive/yolov5/Car-detection-3/test/images/193056_jpg.rf.f57b94838941fa5685480f93b209ed7f.jpg: 640x640 2 Cars, 489.1ms
# image 2/39 /content/drive/MyDrive/yolov5/Car-detection-3/test/images/282948_jpg.rf.bd260a57e57c1de6707525dd2ce3b092.jpg: 640x640 1 Car, 424.2ms
# image 3/39 /content/drive/MyDrive/yolov5/Car-detection-3/test/images/333847_jpg.rf.26df358bdff3529dd24a4c6a16e0d680.jpg: 640x640 1 Car, 407.1ms
# image 4/39 /content/drive/MyDrive/yolov5/Car-detection-3/test/images/34715_jpg.rf.790311c9ac1afa6bfadb89da81607b53.jpg: 640x640 3 Cars, 437.9ms
# image 5/39 /content/drive/MyDrive/yolov5/Car-detection-3/test/images/348157_jpg.rf.e75d8ab7b13464cbe4af22b1fd5fbeae.jpg: 640x640 1 Car, 384.0ms
# image 6/39 /content/drive/MyDrive/yolov5/Car-detection-3/test/images/349172_jpg.rf.6ab7b2b46d9834fb318712a809de4de0.jpg: 640x640 2 Cars, 343.0ms
# image 7/39 /content/drive/MyDrive/yolov5/Car-detection-3/test/images/355833_jpg.rf.7e0ea05f55de9b15e47532aae8cbbc85.jpg: 640x640 3 Cars, 350.3ms
# image 8/39 /content/drive/MyDrive/yolov5/Car-detection-3/test/images/374506_jpg.rf.0a7bc2a6bc7fa8b3b2e1bf3a2a4e27cb.jpg: 640x640 1 Car, 365.7ms
# image 9/39 /content/drive/MyDrive/yolov5/Car-detection-3/test/images/378100_jpg.rf.eda45ef961ec696cc3db31c860d7f0a1.jpg: 640x640 1 Car, 355.8ms
# image 10/39 /content/drive/MyDrive/yolov5/Car-detection-3/test/images/414882_jpg.rf.ec8d8612b75101b97125cc51291927e6.jpg: 640x640 1 Car, 345.3ms
# image 11/39 /content/drive/MyDrive/yolov5/Car-detection-3/test/images/454739_jpg.rf.d0fae76fb63c846546d6d8aa00dd4705.jpg: 640x640 2 Cars, 340.6ms
# image 12/39 /content/drive/MyDrive/yolov5/Car-detection-3/test/images/525987_jpg.rf.60cb561feb9c0a7db13c9ae5b08d13d0.jpg: 640x640 6 Cars, 353.4ms
# image 13/39 /content/drive/MyDrive/yolov5/Car-detection-3/test/images/564579_jpg.rf.9f4938f63fe3ef60983739a186eea752.jpg: 640x640 2 Cars, 349.1ms
# image 14/39 /content/drive/MyDrive/yolov5/Car-detection-3/test/images/597672_jpg.rf.80f8a3175af72d6c076e109d376a3810.jpg: 640x640 1 Car, 514.7ms
# image 15/39 /content/drive/MyDrive/yolov5/Car-detection-3/test/images/646657_jpg.rf.3fd86eafd2dd0e70be7740d3b3f31836.jpg: 640x640 1 Car, 588.7ms
# image 16/39 /content/drive/MyDrive/yolov5/Car-detection-3/test/images/68844_jpg.rf.e55d8dc7f8e2c43f43d3ba03486e795b.jpg: 640x640 1 Car, 569.2ms
# image 17/39 /content/drive/MyDrive/yolov5/Car-detection-3/test/images/691077_jpg.rf.7f26920f208151f125560023e8b7ccb2.jpg: 640x640 2 Cars, 583.5ms
# image 18/39 /content/drive/MyDrive/yolov5/Car-detection-3/test/images/694343_jpg.rf.ce518936425e26323eb4c2d7d6f68442.jpg: 640x640 1 Car, 454.3ms
# image 19/39 /content/drive/MyDrive/yolov5/Car-detection-3/test/images/773514_jpg.rf.8efec423d9f5b1a5e4ea46a253fc5f15.jpg: 640x640 1 Car, 355.3ms
# image 20/39 /content/drive/MyDrive/yolov5/Car-detection-3/test/images/842548_jpg.rf.06226ce49d67bd21b4db6143a97b8524.jpg: 640x640 1 Car, 355.4ms
# image 21/39 /content/drive/MyDrive/yolov5/Car-detection-3/test/images/847209_jpg.rf.a1d51fa938578a744c4934ea10a84c1f.jpg: 640x640 2 Cars, 366.2ms
# image 22/39 /content/drive/MyDrive/yolov5/Car-detection-3/test/images/877171_jpg.rf.55bceae41db13d78a45968d948f2879b.jpg: 640x640 1 Car, 350.3ms
# image 23/39 /content/drive/MyDrive/yolov5/Car-detection-3/test/images/912422_jpg.rf.abfb69ddbdb6cfefe57a91a49550b2d2.jpg: 640x640 3 Cars, 361.8ms
# image 24/39 /content/drive/MyDrive/yolov5/Car-detection-3/test/images/913897_jpg.rf.79c04eefb40049288f4d7f3f91966a20.jpg: 640x640 1 Car, 352.4ms
# image 25/39 /content/drive/MyDrive/yolov5/Car-detection-3/test/images/961292_jpg.rf.0d9b6e2460f921de1231fec799867829.jpg: 640x640 2 Cars, 356.8ms
# image 26/39 /content/drive/MyDrive/yolov5/Car-detection-3/test/images/images-100-_jpg.rf.ad7f0cb4120d8cd4f40049bb6df82110.jpg: 640x640 1 Car, 348.1ms
# image 27/39 /content/drive/MyDrive/yolov5/Car-detection-3/test/images/images-12-_jpg.rf.d0516c47bc77450ac4dd2bc24ecc077c.jpg: 640x640 1 Car, 357.8ms
# image 28/39 /content/drive/MyDrive/yolov5/Car-detection-3/test/images/images-29-_jpg.rf.c17de94dab2a22406bae9af1fe5544ac.jpg: 640x640 1 Car, 357.3ms
# image 29/39 /content/drive/MyDrive/yolov5/Car-detection-3/test/images/images-38-_jpg.rf.dda55c1ae6bbd26c459cb257581ed91c.jpg: 640x640 2 Cars, 366.2ms
# image 30/39 /content/drive/MyDrive/yolov5/Car-detection-3/test/images/images-39-_jpg.rf.22d08e72742a2d98c0944d19afd21c06.jpg: 640x640 1 Car, 345.0ms
# image 31/39 /content/drive/MyDrive/yolov5/Car-detection-3/test/images/images-41-_jpg.rf.753792c7f5def49573ec42f1a384bc88.jpg: 640x640 1 Car, 355.9ms
# image 32/39 /content/drive/MyDrive/yolov5/Car-detection-3/test/images/images-46-_jpg.rf.9e38769ef2d418cc72676b68e183ace2.jpg: 640x640 3 Cars, 344.5ms
# image 33/39 /content/drive/MyDrive/yolov5/Car-detection-3/test/images/images-5-_jpg.rf.929e95d093b04584871fd6b699ad8877.jpg: 640x640 1 Car, 409.2ms
# image 34/39 /content/drive/MyDrive/yolov5/Car-detection-3/test/images/images-60-_jpg.rf.b95a477c80a1cc2c94cd244e6e1a27fb.jpg: 640x640 1 Car, 562.5ms
# image 35/39 /content/drive/MyDrive/yolov5/Car-detection-3/test/images/images-62-_jpg.rf.b86248d5f97a27f5e87862869e60be5b.jpg: 640x640 1 Car, 571.5ms
# image 36/39 /content/drive/MyDrive/yolov5/Car-detection-3/test/images/images-71-_jpg.rf.4141c574c97e0c7b0b89286155d0310c.jpg: 640x640 1 Car, 568.9ms
# image 37/39 /content/drive/MyDrive/yolov5/Car-detection-3/test/images/images-74-_jpg.rf.2ea4c6b1cda202335e52039c38b14f49.jpg: 640x640 1 Car, 538.3ms
# image 38/39 /content/drive/MyDrive/yolov5/Car-detection-3/test/images/images-88-_jpg.rf.bc6860012aefa42574ba6f016c5dfdfe.jpg: 640x640 1 Car, 348.2ms
# image 39/39 /content/drive/MyDrive/yolov5/Car-detection-3/test/images/images-9-_jpg.rf.e181f37aa6f6ab25fefc81afb1bc62a8.jpg: 640x640 1 Car, 361.1ms
# Speed: 2.1ms pre-process, 410.0ms inference, 1.6ms NMS per image at shape (1, 3, 640, 640)
# Results saved to drive/MyDrive/yolov5/runs/detect/exp3

# %% [markdown]
# Vậy file best.pt là gì?
# -> File best.pt là tập tin chứa trọng số của mô hình tốt nhất được lưu lại trong quá trình huấn luyện. Khi mô hình được huấn luyện, trọng số của nó sẽ được cập nhật liên tục theo từng epoch. Tập tin best.pt sẽ lưu lại trọng số tương ứng với epoch nào đó mà mô hình có hiệu suất tốt nhất trên tập dữ liệu kiểm tra (validation set). Nó được sử dụng để tải lại trọng số của mô hình đã được huấn luyện trước đó và sử dụng để tiếp tục huấn luyện hoặc để dự đoán trên các bộ dữ liệu mới.

# %% [markdown]
# Sau khi train mô hình YOLOv5, chúng ta sẽ có một mô hình đã được đào tạo để phát hiện các đối tượng trong hình ảnh. Tuy nhiên, để sử dụng mô hình này để phát hiện đối tượng trong các hình ảnh mới, chúng ta cần thực hiện quá trình dự đoán (inference) trên các hình ảnh đó.
#
# Việc sử dụng tập lệnh detect.py và mô hình được đào tạo (best.pt) sẽ giúp cho việc thực hiện dự đoán trên các hình ảnh mới trở nên dễ dàng hơn. Để thực hiện phát hiện đối tượng trên các hình ảnh mới, chúng ta chỉ cần đưa các hình ảnh đó vào thư mục được chỉ định và chạy tập lệnh detect.py với mô hình được đào tạo để tạo ra các kết quả phát hiện. Kết quả sẽ được lưu trữ trong các tệp ảnh mới tạo ra, cung cấp cho chúng ta thông tin về các đối tượng được phát hiện trong hình ảnh đó.
